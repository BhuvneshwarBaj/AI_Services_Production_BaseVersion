# %%
import services_LLM as sllm
import pandas as pd

# %%
df= pd.read_csv("Smart_Company.csv")

# %%
model = sllm.get_phi4_model()
# Out:
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# Device set to use cuda:0

# %%
pred = sllm.execute_featuretype_LLM(df,model)
# Out:
# /home/ptsialis/Schreibtisch/services_combine/feature_generator.py:247: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   data1 = data1.fillna(0)
# Index 0, Doing Feature 'total'
#
# ------------------------------------------------------------------
#
# Index 1, Doing Feature 'datetime_utc'
#
# ------------------------------------------------------------------
#
# Index 2, Doing Feature 'PV'
#
# ------------------------------------------------------------------
#
# Index 3, Doing Feature 'CHP'
#
# ------------------------------------------------------------------
#
# Index 4, Doing Feature 'mean_global_irradiance'
#
# ------------------------------------------------------------------
#
# Index 5, Doing Feature 'Air_temp'
#
# ...

# %%
pred
# Out:
# ['Numeric',
#  'Datetime',
#  'Not-Generalizable',
#  'Numeric',
#  'Numeric',
#  'Numeric',
#  'Categorical',
#  'Categorical']

# %%
table,p1,p2 =sllm.execute_personal_llm(df,model)
# Out:
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset

# %%
table
# Out:
#                    Column Classification
# 0                   total   Non-personal
# 1            datetime_utc   Non-personal
# 2                      PV   Non-personal
# 3                     CHP   Non-personal
# 4  mean_global_irradiance   Non-personal
# 5                Air_temp   Non-personal
# 6        Facility_Manager       Personal
# 7       Engine_test_stand   Non-personal
